# %%
import tkinter as tk
from tkinter import messagebox
from PIL import ImageTk, Image


root=tk.Tk()
win=tk.Frame(root)
L=tk.Label(root,text="TIC TAC TOE")
L.config(font=("Roboto",14))
player=1
def loc():
    B1.config(state="disabled")
    B2.config(state="disabled")
    B3.config(state="disabled")
    B4.config(state="disabled")
    B5.config(state="disabled")
    B6.config(state="disabled")
    B7.config(state="disabled")
    B8.config(state="disabled")
    B9.config(state="disabled")
    
def val_change(B):
    global player
    if player==1:
        B['text']='X'
        B.config(state="disabled")
        player=2
    else:
        B['text']='O'
        B.config(state="disabled")
        player=1
    
    if B1['text']==B2['text']==B3['text']:
        if B1['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B1['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()
    
    if B4['text']==B5['text']==B6['text']:
        if B4['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B4['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()

    if B7['text']==B8['text']==B9['text']:
        if B7['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B7['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()
    if B1['text']==B4['text']==B7['text']:
        if B7['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B7['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()
    if B2['text']==B5['text']==B8['text']:
        if B2['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B2['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()
    if B3['text']==B6['text']==B9['text']:
        if B9['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B9['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()
    if B1['text']==B5['text']==B9['text']:
        if B1['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B1['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()
            
    if B7['text']==B3['text']==B5['text']:
        if B7['text']=='X':
            messagebox.showinfo('Winner','Player 1 is the winner')
            loc()
        if B7['text']=='O':
            messagebox.showinfo('Winner','Player 2 is the winner')
            loc()
B1=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B1))
B2=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B2))
B3=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B3))
B4=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B4))
B5=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B5))
B6=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B6))
B7=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B7))
B8=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B8))
B9=tk.Button(win,text='',font=('Roboto',18),command=lambda: val_change(B9))

B1.grid(column=0,row=0,pady=1)
B2.grid(column=1,row=0,pady=1)
B3.grid(column=2,row=0,pady=1)
B4.grid(column=0,row=1,pady=1)
B5.grid(column=1,row=1,pady=1)
B6.grid(column=2,row=1,pady=1)
B7.grid(column=0,row=2)
B8.grid(column=1,row=2)
B9.grid(column=2,row=2)

B1.config(width=6,height=3)
B2.config(width=6,height=3)
B3.config(width=6,height=3)
B4.config(width=6,height=3)
B5.config(width=6,height=3)
B6.config(width=6,height=3)
B7.config(width=6,height=3)
B8.config(width=6,height=3)
B9.config(width=6,height=3)
#val1.set(" ")
#background_label.pack()
L.pack()
win.pack()
root.geometry("300x340")
root.mainloop()
